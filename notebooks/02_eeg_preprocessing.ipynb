# %% [markdown]
# # EEG Preprocessing & Spectral Slope
#
# This notebook focuses on preprocessing EEG data recorded during deep sleep and extracting spectral properties related to unconscious brain states.
#
# Main goals:
# - EEG filtering
# - artifact inspection
# - spectral analysis
# - estimation of spectral exponent (1/f slope)

# %%
import mne
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from scipy.optimize import curve_fit

# %%
raw = mne.io.read_raw_brainvision(
    "../data/raw/sleep_data/sub_23/eeg/sub-23_task-sleep_run-3_eeg.vhdr",
    preload=True
)
# Out:
# Extracting parameters from ../data/raw/sleep_data/sub_23/eeg/sub-23_task-sleep_run-3_eeg.vhdr...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 raw = mne.io.read_raw_brainvision(
#       2     "../data/raw/sleep_data/sub_23/eeg/sub-23_task-sleep_run-3_eeg.vhdr",
#       3     preload=True
#       4 )
#
# File ~\Desktop\data_prjcts\different-paths-to-unresponsiveness\.venv\Lib\site-packages\mne\io\brainvision\brainvision.py:999, in read_raw_brainvision(vhdr_fname, eog, misc, scale, ignore_marker_types, preload, verbose)
#     935 @fill_doc
#     936 def read_raw_brainvision(
#     937     vhdr_fname,
#    (...)    943     verbose=None,
#     944 ) -> RawBrainVision:
#     945     """Reader for Brain Vision EEG file.
#     946
#     947     Parameters
#    (...)    997     attribute of the returned object and is not converted to an annotation.
#     998     """
# --> 999     return RawBrainVision(
#    1000         vhdr_fname=vhdr_fname,
#    1001         eog=eog,
#    1002         misc=misc,
#    1003         scale=scale,
#    1004         ignore_marker_types=ignore_marker_types,
#    1005         preload=preload,
#    1006         verbose=verbose,
#    1007     )
#
# File <decorator-gen-220>:12, in __init__(self, vhdr_fname, eog, misc, scale, ignore_marker_types, preload, verbose)
#
# File ~\Desktop\data_prjcts\different-paths-to-unresponsiveness\.venv\Lib\site-packages\mne\io\brainvision\brainvision.py:110, in RawBrainVision.__init__(self, vhdr_fname, eog, misc, scale, ignore_marker_types, preload, verbose)
#      99 ext = op.splitext(hdr_fname)[-1]
#     100 ahdr_format = True if ext == ".ahdr" else False
#     101 (
#     102     info,
#     103     data_fname,
#     104     fmt,
#     105     order,
#     106     n_samples,
#     107     mrk_fname,
#     108     montage,
#     109     orig_units,
# --> 110 ) = _get_hdr_info(hdr_fname, eog, misc, scale)
#     112 with open(data_fname, "rb") as f:
#     113     if isinstance(fmt, dict):  # ASCII, this will be slow :(
#
# File ~\Desktop\data_prjcts\different-paths-to-unresponsiveness\.venv\Lib\site-packages\mne\io\brainvision\brainvision.py:537, in _get_hdr_info(hdr_fname, eog, misc, scale)
#     531 if ext not in (".vhdr", ".ahdr"):
#     532     raise OSError(
#     533         "The header file must be given to read the data, not a file with extension "
#     534         f"'{ext}'."
#     535     )
# --> 537 settings, cfg, cinfostr, info = _aux_hdr_info(hdr_fname)
#     538 info._unlocked = True
#     540 order = cfg.get(cinfostr, "DataOrientation")
#
# File ~\Desktop\data_prjcts\different-paths-to-unresponsiveness\.venv\Lib\site-packages\mne\io\brainvision\brainvision.py:437, in _aux_hdr_info(hdr_fname)
#     435 def _aux_hdr_info(hdr_fname):
#     436     """Aux function for _get_hdr_info."""
# --> 437     with open(hdr_fname, "rb") as f:
#     438         # extract the first section to resemble a cfg
#     439         header = f.readline()
#     440         codepage = "utf-8"
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\Lenovo\\Desktop\\data_prjcts\\data\\raw\\sleep_data\\sub_23\\eeg\\sub-23_task-sleep_run-3_eeg.vhdr'
